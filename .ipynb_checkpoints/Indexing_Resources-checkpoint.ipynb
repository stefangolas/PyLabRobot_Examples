# %%
from pylabrobot.liquid_handling import LiquidHandler
from pylabrobot.liquid_handling.backends.simulation.simulator_backend import SimulatorBackend
from pylabrobot.liquid_handling.backends import ChatterBoxBackend
from pylabrobot.resources.hamilton import STARLetDeck
from pylabrobot.resources.opentrons import OTDeck

from pylabrobot.resources import (
    TIP_CAR_480_A00,
    PLT_CAR_L5AC_A00,
    Cos_96_DW_1mL,
    STF_L
)

sb = SimulatorBackend(open_browser=False)
lh = LiquidHandler(backend=sb, deck=STARLetDeck())

# %%
await lh.setup()
# Out:
# Websocket server started at http://127.0.0.1:2121
# C:\Users\stefa\PyLabRobot_Notebooks
# Setup complete
# C:\Users\stefa\PyLabRobot_Notebooks
# File server started at http://127.0.0.1:1337 . Open this URL in your browser.

# %%
sb.wait_for_connection()

# %%
from pylabrobot.resources import (
    TIP_CAR_480_A00,
    PLT_CAR_L5AC_A00,
    Cos_96_DW_1mL,
    HTF_L
)
tip_car = TIP_CAR_480_A00(name='tip carrier')
tip_car[0] = tips = HTF_L(name='tips_01')
tip_car[1] = HTF_L(name='tips_02')
tip_car[2] = HTF_L(name='tips_03')
tip_car[3] = HTF_L(name='tips_04')
tip_car[4] = HTF_L(name='tips_05')
lh.deck.assign_child_resource(tip_car, rails=15)
plt_car = PLT_CAR_L5AC_A00(name='plate carrier')
plt_car[0] = plate = Cos_96_DW_1mL(name='plate_01')
plt_car[1] = Cos_96_DW_1mL(name='plate_02')
plt_car[2] = Cos_96_DW_1mL(name='plate_03')
lh.deck.assign_child_resource(plt_car, rails=8)

# %%
#lh.deck.summary()
lh.deck.serialize()
# Out:
# {'name': 'deck',
#  'type': 'HamiltonDeck',
#  'size_x': 1360,
#  'size_y': 653.5,
#  'size_z': 900,
#  'location': {'x': 0, 'y': 0, 'z': 0},
#  'category': 'deck',
#  'children': [{'name': 'trash',
#    'type': 'Trash',
#    'size_x': 0,
#    'size_y': 241.2,
#    'size_z': 0,
#    'location': {'x': 800, 'y': 190.6, 'z': 137.1},
#    'category': None,
#    'model': None,
#    'children': [],
#    'parent_name': 'deck'},
#   {'name': 'tip carrier',
#    'type': 'TipCarrier',
#    'size_x': 135.0,
#    'size_y': 497.0,
#    'size_z': 130.0,
#    'location': {'x': 415.0, 'y': 63, 'z': 100},
#    'category': 'tip_carrier',
#    'model': 'TIP_CAR_480_A00',
#    'children': [{'spot': 0,
#      'name': 'carrier-tip carrier-spot-0',
#      'type': 'CarrierSite',
#      'size_x': 122.4,
#      'size_y': 82.6,
#      'size_z': 0,
#      'location': {'x': 6.2, 'y': 10.0, 'z': 114.95},
#      'category': 'carrier_site',
#      'model': None,
#      'children': [{'name': 'tips_01',
#        'type': 'TipRack',
#        'size_x': 122.4,
#        'size_y': 82.6,
#        'size_z': 20.0,
#        'location': {'x': 0, 'y': 0, 'z': 0},
#        'category': 'tip_rack',
#        'model': 'HTF_L',
#        'children': [{'name': 'tips_01_tipspot_0_0',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 7.2, 'y': 68.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_0_1',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 7.2, 'y': 59.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_0_2',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 7.2, 'y': 50.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_0_3',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 7.2, 'y': 41.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_0_4',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 7.2, 'y': 32.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_0_5',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 7.2, 'y': 23.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_0_6',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 7.2, 'y': 14.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_0_7',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 7.2, 'y': 5.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_1_0',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 16.2, 'y': 68.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_1_1',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 16.2, 'y': 59.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_1_2',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 16.2, 'y': 50.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_1_3',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 16.2, 'y': 41.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_1_4',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 16.2, 'y': 32.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_1_5',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 16.2, 'y': 23.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_1_6',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 16.2, 'y': 14.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_1_7',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 16.2, 'y': 5.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_2_0',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 25.2, 'y': 68.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_2_1',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 25.2, 'y': 59.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_2_2',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 25.2, 'y': 50.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_2_3',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 25.2, 'y': 41.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_2_4',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 25.2, 'y': 32.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_2_5',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 25.2, 'y': 23.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_2_6',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 25.2, 'y': 14.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_2_7',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 25.2, 'y': 5.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_3_0',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 34.2, 'y': 68.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_3_1',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 34.2, 'y': 59.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_3_2',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 34.2, 'y': 50.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_3_3',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 34.2, 'y': 41.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_3_4',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 34.2, 'y': 32.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_3_5',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 34.2, 'y': 23.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_3_6',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 34.2, 'y': 14.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_3_7',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 34.2, 'y': 5.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_4_0',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 43.2, 'y': 68.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_4_1',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 43.2, 'y': 59.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_4_2',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 43.2, 'y': 50.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_4_3',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 43.2, 'y': 41.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_4_4',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 43.2, 'y': 32.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_4_5',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 43.2, 'y': 23.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_4_6',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 43.2, 'y': 14.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_4_7',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 43.2, 'y': 5.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_5_0',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 52.2, 'y': 68.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_5_1',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 52.2, 'y': 59.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_5_2',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 52.2, 'y': 50.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_5_3',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 52.2, 'y': 41.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_5_4',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 52.2, 'y': 32.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_5_5',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 52.2, 'y': 23.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_5_6',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 52.2, 'y': 14.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_5_7',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 52.2, 'y': 5.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_6_0',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 61.2, 'y': 68.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_6_1',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 61.2, 'y': 59.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_6_2',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 61.2, 'y': 50.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_6_3',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 61.2, 'y': 41.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_6_4',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 61.2, 'y': 32.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_6_5',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 61.2, 'y': 23.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_6_6',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 61.2, 'y': 14.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_6_7',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 61.2, 'y': 5.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_7_0',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 70.2, 'y': 68.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_7_1',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 70.2, 'y': 59.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_7_2',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 70.2, 'y': 50.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_7_3',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 70.2, 'y': 41.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_7_4',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 70.2, 'y': 32.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_7_5',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 70.2, 'y': 23.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_7_6',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 70.2, 'y': 14.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_7_7',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 70.2, 'y': 5.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_8_0',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 79.2, 'y': 68.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_8_1',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 79.2, 'y': 59.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_8_2',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 79.2, 'y': 50.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_8_3',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 79.2, 'y': 41.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_8_4',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 79.2, 'y': 32.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_8_5',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 79.2, 'y': 23.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_8_6',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 79.2, 'y': 14.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_8_7',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 79.2, 'y': 5.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_9_0',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 88.2, 'y': 68.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_9_1',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 88.2, 'y': 59.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_9_2',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 88.2, 'y': 50.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_9_3',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 88.2, 'y': 41.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_9_4',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 88.2, 'y': 32.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_9_5',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 88.2, 'y': 23.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_9_6',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 88.2, 'y': 14.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_9_7',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 88.2, 'y': 5.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_10_0',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 97.2, 'y': 68.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_10_1',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 97.2, 'y': 59.3, 'z': -83.5},
#          'category': 'tip_spot',
#          'model': None,
#          'children': [],
#          'parent_name': 'tips_01',
#          'prototype_tip': {'type': 'HamiltonTip',
#           'total_tip_length': 95.1,
#           'has_filter': True,
#           'maximal_volume': 1065,
#           'pickup_method': 'OUT_OF_RACK',
#           'tip_size': 'HIGH_VOLUME'},
#          'has_tip': True},
#         {'name': 'tips_01_tipspot_10_2',
#          'type': 'TipSpot',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 0,
#          'location': {'x': 97.2, 'y': 50.3, 'z': -83.5},
#          'category': 'tip_spot',
# ...
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_6_7',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 63.5, 'y': 7.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_7_0',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 72.5, 'y': 70.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_7_1',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 72.5, 'y': 61.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_7_2',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 72.5, 'y': 52.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_7_3',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 72.5, 'y': 43.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_7_4',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 72.5, 'y': 34.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_7_5',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 72.5, 'y': 25.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_7_6',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 72.5, 'y': 16.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_7_7',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 72.5, 'y': 7.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_8_0',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 81.5, 'y': 70.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_8_1',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 81.5, 'y': 61.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_8_2',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 81.5, 'y': 52.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_8_3',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 81.5, 'y': 43.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_8_4',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 81.5, 'y': 34.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_8_5',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 81.5, 'y': 25.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_8_6',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 81.5, 'y': 16.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_8_7',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 81.5, 'y': 7.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_9_0',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 90.5, 'y': 70.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_9_1',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 90.5, 'y': 61.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_9_2',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 90.5, 'y': 52.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_9_3',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 90.5, 'y': 43.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_9_4',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 90.5, 'y': 34.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_9_5',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 90.5, 'y': 25.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_9_6',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 90.5, 'y': 16.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_9_7',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 90.5, 'y': 7.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_10_0',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 99.5, 'y': 70.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_10_1',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 99.5, 'y': 61.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_10_2',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 99.5, 'y': 52.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_10_3',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 99.5, 'y': 43.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_10_4',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 99.5, 'y': 34.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_10_5',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 99.5, 'y': 25.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_10_6',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 99.5, 'y': 16.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_10_7',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 99.5, 'y': 7.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_11_0',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 108.5, 'y': 70.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_11_1',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 108.5, 'y': 61.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_11_2',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 108.5, 'y': 52.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_11_3',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 108.5, 'y': 43.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_11_4',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 108.5, 'y': 34.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_11_5',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 108.5, 'y': 25.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_11_6',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 108.5, 'y': 16.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398},
#         {'name': 'plate_03_well_11_7',
#          'type': 'Well',
#          'size_x': 9.0,
#          'size_y': 9.0,
#          'size_z': 9,
#          'location': {'x': 108.5, 'y': 7.0, 'z': 1.0},
#          'category': 'well',
#          'model': None,
#          'children': [],
#          'parent_name': 'plate_03',
#          'volume': 0,
#          'max_volume': 572.5552611167398}],
#        'parent_name': 'carrier-plate carrier-spot-2',
#        'num_items_x': 12,
#        'num_items_y': 8,
#        'one_dot_max': 40.0}],
#      'parent_name': 'plate carrier'},
#     {'spot': 3,
#      'name': 'carrier-plate carrier-spot-3',
#      'type': 'CarrierSite',
#      'size_x': 127.0,
#      'size_y': 86.0,
#      'size_z': 0,
#      'location': {'x': 4.0, 'y': 296.5, 'z': 86.15},
#      'category': 'carrier_site',
#      'model': None,
#      'children': [],
#      'parent_name': 'plate carrier'},
#     {'spot': 4,
#      'name': 'carrier-plate carrier-spot-4',
#      'type': 'CarrierSite',
#      'size_x': 127.0,
#      'size_y': 86.0,
#      'size_z': 0,
#      'location': {'x': 4.0, 'y': 392.5, 'z': 86.15},
#      'category': 'carrier_site',
#      'model': None,
#      'children': [],
#      'parent_name': 'plate carrier'}],
#    'parent_name': 'deck'}],
#  'parent_name': None,
#  'num_rails': 30,
#  'no_trash': True}

# %%
lh.deck.save('save_deck.json')

# %%
import os
os.getcwd()
# Out:
# 'c:\\users\\stefa\\pylabrobot\\pylabrobot\\liquid_handling\\backends\\simulation\\simulator'

# %%
tiprack = lh.get_resource("tips_01")

# %%
await sb.fill_tip_rack(tiprack)

# %%
tips4 = lh.get_resource("tips_04")
await sb.edit_tips(tips4, pattern=[[True]*6 + [False]*6]*8)
await sb.edit_tips(lh.get_resource("tips_03"), pattern=[[True, False]*6]*8)
await sb.edit_tips(lh.get_resource("tips_02"), pattern=[[True, True, False, False]*3]*8)

# %%
plate_1 = lh.get_resource("plate_01")
plate_2 = lh.get_resource("plate_02")
await sb.adjust_well_volume(plate_1, pattern=[[500]*12]*8)
await sb.adjust_well_volume(plate_2, pattern=[[100, 500]*6]*8)

# %%
plate_1.set_well_volumes([[500]*12]*8)
plate_2.set_well_volumes([[100, 500]*6]*8)

# %%
tip_0 = lh.get_resource("tips_01")
await lh.pick_up_tips(tip_0["A1", "B2", "C3", "D4"])
await lh.drop_tips(tip_0["A1", "B2", "C3", "D4"])
# Out:
# Picking up tips [Pickup(tip=TipSpot(name=tips_01_tipspot_0_0, location=(007.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot), offset=Default), Pickup(tip=TipSpot(name=tips_01_tipspot_1_1, location=(016.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot), offset=Default), Pickup(tip=TipSpot(name=tips_01_tipspot_2_2, location=(025.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot), offset=Default), Pickup(tip=TipSpot(name=tips_01_tipspot_3_3, location=(034.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot), offset=Default)].
# Dropping tips [Drop(tip=TipSpot(name=tips_01_tipspot_0_0, location=(007.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot), offset=Default), Drop(tip=TipSpot(name=tips_01_tipspot_1_1, location=(016.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot), offset=Default), Drop(tip=TipSpot(name=tips_01_tipspot_2_2, location=(025.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot), offset=Default), Drop(tip=TipSpot(name=tips_01_tipspot_3_3, location=(034.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot), offset=Default)].

# %%
await lh.pick_up_tips(tip_0["A1"])
await lh.aspirate(plate["A2"], vols=[300])
await lh.dispense(plate_2["A1"], vols=[300])
await lh.drop_tips(tip_0["A1"])

# %%
lh.deck.__dict__
# Out:
# {'_name': 'deck',
#  '_size_x': 1360,
#  '_size_y': 653.5,
#  '_size_z': 900,
#  'category': 'deck',
#  'model': None,
#  'location': Coordinate(0, 0, 0),
#  'parent': None,
#  'children': [Trash(name=trash, location=(800.000, 190.600, 137.100), size_x=0, size_y=241.2, size_z=0, category=None),
#   TipCarrier(name=tip carrier, location=(415.000, 063.000, 100.000), size_x=135.0, size_y=497.0, size_z=130.0, category=tip_carrier),
#   PlateCarrier(name=plate carrier, location=(257.500, 063.000, 100.000), size_x=135.0, size_y=497.0, size_z=130.0, category=plate_carrier)],
#  'rotation': 0,
#  'resources': {'trash': Trash(name=trash, location=(800.000, 190.600, 137.100), size_x=0, size_y=241.2, size_z=0, category=None),
#   'tips_01_tipspot_0_0': TipSpot(name=tips_01_tipspot_0_0, location=(007.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_0_1': TipSpot(name=tips_01_tipspot_0_1, location=(007.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_0_2': TipSpot(name=tips_01_tipspot_0_2, location=(007.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_0_3': TipSpot(name=tips_01_tipspot_0_3, location=(007.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_0_4': TipSpot(name=tips_01_tipspot_0_4, location=(007.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_0_5': TipSpot(name=tips_01_tipspot_0_5, location=(007.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_0_6': TipSpot(name=tips_01_tipspot_0_6, location=(007.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_0_7': TipSpot(name=tips_01_tipspot_0_7, location=(007.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_1_0': TipSpot(name=tips_01_tipspot_1_0, location=(016.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_1_1': TipSpot(name=tips_01_tipspot_1_1, location=(016.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_1_2': TipSpot(name=tips_01_tipspot_1_2, location=(016.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_1_3': TipSpot(name=tips_01_tipspot_1_3, location=(016.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_1_4': TipSpot(name=tips_01_tipspot_1_4, location=(016.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_1_5': TipSpot(name=tips_01_tipspot_1_5, location=(016.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_1_6': TipSpot(name=tips_01_tipspot_1_6, location=(016.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_1_7': TipSpot(name=tips_01_tipspot_1_7, location=(016.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_2_0': TipSpot(name=tips_01_tipspot_2_0, location=(025.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_2_1': TipSpot(name=tips_01_tipspot_2_1, location=(025.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_2_2': TipSpot(name=tips_01_tipspot_2_2, location=(025.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_2_3': TipSpot(name=tips_01_tipspot_2_3, location=(025.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_2_4': TipSpot(name=tips_01_tipspot_2_4, location=(025.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_2_5': TipSpot(name=tips_01_tipspot_2_5, location=(025.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_2_6': TipSpot(name=tips_01_tipspot_2_6, location=(025.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_2_7': TipSpot(name=tips_01_tipspot_2_7, location=(025.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_3_0': TipSpot(name=tips_01_tipspot_3_0, location=(034.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_3_1': TipSpot(name=tips_01_tipspot_3_1, location=(034.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_3_2': TipSpot(name=tips_01_tipspot_3_2, location=(034.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_3_3': TipSpot(name=tips_01_tipspot_3_3, location=(034.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_3_4': TipSpot(name=tips_01_tipspot_3_4, location=(034.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_3_5': TipSpot(name=tips_01_tipspot_3_5, location=(034.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_3_6': TipSpot(name=tips_01_tipspot_3_6, location=(034.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_3_7': TipSpot(name=tips_01_tipspot_3_7, location=(034.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_4_0': TipSpot(name=tips_01_tipspot_4_0, location=(043.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_4_1': TipSpot(name=tips_01_tipspot_4_1, location=(043.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_4_2': TipSpot(name=tips_01_tipspot_4_2, location=(043.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_4_3': TipSpot(name=tips_01_tipspot_4_3, location=(043.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_4_4': TipSpot(name=tips_01_tipspot_4_4, location=(043.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_4_5': TipSpot(name=tips_01_tipspot_4_5, location=(043.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_4_6': TipSpot(name=tips_01_tipspot_4_6, location=(043.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_4_7': TipSpot(name=tips_01_tipspot_4_7, location=(043.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_5_0': TipSpot(name=tips_01_tipspot_5_0, location=(052.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_5_1': TipSpot(name=tips_01_tipspot_5_1, location=(052.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_5_2': TipSpot(name=tips_01_tipspot_5_2, location=(052.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_5_3': TipSpot(name=tips_01_tipspot_5_3, location=(052.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_5_4': TipSpot(name=tips_01_tipspot_5_4, location=(052.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_5_5': TipSpot(name=tips_01_tipspot_5_5, location=(052.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_5_6': TipSpot(name=tips_01_tipspot_5_6, location=(052.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_5_7': TipSpot(name=tips_01_tipspot_5_7, location=(052.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_6_0': TipSpot(name=tips_01_tipspot_6_0, location=(061.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_6_1': TipSpot(name=tips_01_tipspot_6_1, location=(061.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_6_2': TipSpot(name=tips_01_tipspot_6_2, location=(061.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_6_3': TipSpot(name=tips_01_tipspot_6_3, location=(061.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_6_4': TipSpot(name=tips_01_tipspot_6_4, location=(061.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_6_5': TipSpot(name=tips_01_tipspot_6_5, location=(061.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_6_6': TipSpot(name=tips_01_tipspot_6_6, location=(061.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_6_7': TipSpot(name=tips_01_tipspot_6_7, location=(061.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_7_0': TipSpot(name=tips_01_tipspot_7_0, location=(070.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_7_1': TipSpot(name=tips_01_tipspot_7_1, location=(070.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_7_2': TipSpot(name=tips_01_tipspot_7_2, location=(070.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_7_3': TipSpot(name=tips_01_tipspot_7_3, location=(070.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_7_4': TipSpot(name=tips_01_tipspot_7_4, location=(070.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_7_5': TipSpot(name=tips_01_tipspot_7_5, location=(070.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_7_6': TipSpot(name=tips_01_tipspot_7_6, location=(070.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_7_7': TipSpot(name=tips_01_tipspot_7_7, location=(070.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_8_0': TipSpot(name=tips_01_tipspot_8_0, location=(079.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_8_1': TipSpot(name=tips_01_tipspot_8_1, location=(079.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_8_2': TipSpot(name=tips_01_tipspot_8_2, location=(079.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_8_3': TipSpot(name=tips_01_tipspot_8_3, location=(079.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_8_4': TipSpot(name=tips_01_tipspot_8_4, location=(079.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_8_5': TipSpot(name=tips_01_tipspot_8_5, location=(079.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_8_6': TipSpot(name=tips_01_tipspot_8_6, location=(079.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_8_7': TipSpot(name=tips_01_tipspot_8_7, location=(079.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_9_0': TipSpot(name=tips_01_tipspot_9_0, location=(088.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_9_1': TipSpot(name=tips_01_tipspot_9_1, location=(088.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_9_2': TipSpot(name=tips_01_tipspot_9_2, location=(088.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_9_3': TipSpot(name=tips_01_tipspot_9_3, location=(088.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_9_4': TipSpot(name=tips_01_tipspot_9_4, location=(088.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_9_5': TipSpot(name=tips_01_tipspot_9_5, location=(088.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_9_6': TipSpot(name=tips_01_tipspot_9_6, location=(088.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_9_7': TipSpot(name=tips_01_tipspot_9_7, location=(088.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_10_0': TipSpot(name=tips_01_tipspot_10_0, location=(097.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_10_1': TipSpot(name=tips_01_tipspot_10_1, location=(097.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_10_2': TipSpot(name=tips_01_tipspot_10_2, location=(097.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_10_3': TipSpot(name=tips_01_tipspot_10_3, location=(097.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_10_4': TipSpot(name=tips_01_tipspot_10_4, location=(097.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_10_5': TipSpot(name=tips_01_tipspot_10_5, location=(097.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_10_6': TipSpot(name=tips_01_tipspot_10_6, location=(097.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_10_7': TipSpot(name=tips_01_tipspot_10_7, location=(097.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_11_0': TipSpot(name=tips_01_tipspot_11_0, location=(106.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_11_1': TipSpot(name=tips_01_tipspot_11_1, location=(106.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_11_2': TipSpot(name=tips_01_tipspot_11_2, location=(106.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_11_3': TipSpot(name=tips_01_tipspot_11_3, location=(106.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_11_4': TipSpot(name=tips_01_tipspot_11_4, location=(106.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_11_5': TipSpot(name=tips_01_tipspot_11_5, location=(106.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_11_6': TipSpot(name=tips_01_tipspot_11_6, location=(106.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01_tipspot_11_7': TipSpot(name=tips_01_tipspot_11_7, location=(106.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_01': TipRack(name=tips_01, size_x=122.4, size_y=82.6, size_z=20.0, location=(000.000, 000.000, 000.000)),
#   'carrier-tip carrier-spot-0': CarrierSite(name=carrier-tip carrier-spot-0, location=(006.200, 010.000, 114.950), size_x=122.4, size_y=82.6, size_z=0, category=carrier_site),
#   'tips_02_tipspot_0_0': TipSpot(name=tips_02_tipspot_0_0, location=(007.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_0_1': TipSpot(name=tips_02_tipspot_0_1, location=(007.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_0_2': TipSpot(name=tips_02_tipspot_0_2, location=(007.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_0_3': TipSpot(name=tips_02_tipspot_0_3, location=(007.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_0_4': TipSpot(name=tips_02_tipspot_0_4, location=(007.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_0_5': TipSpot(name=tips_02_tipspot_0_5, location=(007.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_0_6': TipSpot(name=tips_02_tipspot_0_6, location=(007.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_0_7': TipSpot(name=tips_02_tipspot_0_7, location=(007.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_1_0': TipSpot(name=tips_02_tipspot_1_0, location=(016.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_1_1': TipSpot(name=tips_02_tipspot_1_1, location=(016.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_1_2': TipSpot(name=tips_02_tipspot_1_2, location=(016.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_1_3': TipSpot(name=tips_02_tipspot_1_3, location=(016.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_1_4': TipSpot(name=tips_02_tipspot_1_4, location=(016.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_1_5': TipSpot(name=tips_02_tipspot_1_5, location=(016.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_1_6': TipSpot(name=tips_02_tipspot_1_6, location=(016.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_1_7': TipSpot(name=tips_02_tipspot_1_7, location=(016.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_2_0': TipSpot(name=tips_02_tipspot_2_0, location=(025.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_2_1': TipSpot(name=tips_02_tipspot_2_1, location=(025.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_2_2': TipSpot(name=tips_02_tipspot_2_2, location=(025.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_2_3': TipSpot(name=tips_02_tipspot_2_3, location=(025.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_2_4': TipSpot(name=tips_02_tipspot_2_4, location=(025.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_2_5': TipSpot(name=tips_02_tipspot_2_5, location=(025.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_2_6': TipSpot(name=tips_02_tipspot_2_6, location=(025.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_2_7': TipSpot(name=tips_02_tipspot_2_7, location=(025.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_3_0': TipSpot(name=tips_02_tipspot_3_0, location=(034.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_3_1': TipSpot(name=tips_02_tipspot_3_1, location=(034.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_3_2': TipSpot(name=tips_02_tipspot_3_2, location=(034.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_3_3': TipSpot(name=tips_02_tipspot_3_3, location=(034.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_3_4': TipSpot(name=tips_02_tipspot_3_4, location=(034.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_3_5': TipSpot(name=tips_02_tipspot_3_5, location=(034.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_3_6': TipSpot(name=tips_02_tipspot_3_6, location=(034.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_3_7': TipSpot(name=tips_02_tipspot_3_7, location=(034.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_4_0': TipSpot(name=tips_02_tipspot_4_0, location=(043.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_4_1': TipSpot(name=tips_02_tipspot_4_1, location=(043.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_4_2': TipSpot(name=tips_02_tipspot_4_2, location=(043.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_4_3': TipSpot(name=tips_02_tipspot_4_3, location=(043.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_4_4': TipSpot(name=tips_02_tipspot_4_4, location=(043.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_4_5': TipSpot(name=tips_02_tipspot_4_5, location=(043.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_4_6': TipSpot(name=tips_02_tipspot_4_6, location=(043.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_4_7': TipSpot(name=tips_02_tipspot_4_7, location=(043.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_5_0': TipSpot(name=tips_02_tipspot_5_0, location=(052.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_5_1': TipSpot(name=tips_02_tipspot_5_1, location=(052.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_5_2': TipSpot(name=tips_02_tipspot_5_2, location=(052.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_5_3': TipSpot(name=tips_02_tipspot_5_3, location=(052.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_5_4': TipSpot(name=tips_02_tipspot_5_4, location=(052.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_5_5': TipSpot(name=tips_02_tipspot_5_5, location=(052.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_5_6': TipSpot(name=tips_02_tipspot_5_6, location=(052.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_5_7': TipSpot(name=tips_02_tipspot_5_7, location=(052.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_6_0': TipSpot(name=tips_02_tipspot_6_0, location=(061.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_6_1': TipSpot(name=tips_02_tipspot_6_1, location=(061.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_6_2': TipSpot(name=tips_02_tipspot_6_2, location=(061.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_6_3': TipSpot(name=tips_02_tipspot_6_3, location=(061.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_6_4': TipSpot(name=tips_02_tipspot_6_4, location=(061.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_6_5': TipSpot(name=tips_02_tipspot_6_5, location=(061.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_6_6': TipSpot(name=tips_02_tipspot_6_6, location=(061.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_6_7': TipSpot(name=tips_02_tipspot_6_7, location=(061.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_7_0': TipSpot(name=tips_02_tipspot_7_0, location=(070.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_7_1': TipSpot(name=tips_02_tipspot_7_1, location=(070.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_7_2': TipSpot(name=tips_02_tipspot_7_2, location=(070.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_7_3': TipSpot(name=tips_02_tipspot_7_3, location=(070.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_7_4': TipSpot(name=tips_02_tipspot_7_4, location=(070.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_7_5': TipSpot(name=tips_02_tipspot_7_5, location=(070.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_7_6': TipSpot(name=tips_02_tipspot_7_6, location=(070.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_7_7': TipSpot(name=tips_02_tipspot_7_7, location=(070.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_8_0': TipSpot(name=tips_02_tipspot_8_0, location=(079.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_8_1': TipSpot(name=tips_02_tipspot_8_1, location=(079.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_8_2': TipSpot(name=tips_02_tipspot_8_2, location=(079.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_8_3': TipSpot(name=tips_02_tipspot_8_3, location=(079.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_8_4': TipSpot(name=tips_02_tipspot_8_4, location=(079.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_8_5': TipSpot(name=tips_02_tipspot_8_5, location=(079.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_8_6': TipSpot(name=tips_02_tipspot_8_6, location=(079.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_8_7': TipSpot(name=tips_02_tipspot_8_7, location=(079.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_9_0': TipSpot(name=tips_02_tipspot_9_0, location=(088.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_9_1': TipSpot(name=tips_02_tipspot_9_1, location=(088.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_9_2': TipSpot(name=tips_02_tipspot_9_2, location=(088.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_9_3': TipSpot(name=tips_02_tipspot_9_3, location=(088.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_9_4': TipSpot(name=tips_02_tipspot_9_4, location=(088.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_9_5': TipSpot(name=tips_02_tipspot_9_5, location=(088.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_9_6': TipSpot(name=tips_02_tipspot_9_6, location=(088.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_9_7': TipSpot(name=tips_02_tipspot_9_7, location=(088.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_10_0': TipSpot(name=tips_02_tipspot_10_0, location=(097.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_10_1': TipSpot(name=tips_02_tipspot_10_1, location=(097.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_10_2': TipSpot(name=tips_02_tipspot_10_2, location=(097.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_10_3': TipSpot(name=tips_02_tipspot_10_3, location=(097.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_10_4': TipSpot(name=tips_02_tipspot_10_4, location=(097.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_10_5': TipSpot(name=tips_02_tipspot_10_5, location=(097.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_10_6': TipSpot(name=tips_02_tipspot_10_6, location=(097.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_10_7': TipSpot(name=tips_02_tipspot_10_7, location=(097.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_11_0': TipSpot(name=tips_02_tipspot_11_0, location=(106.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_11_1': TipSpot(name=tips_02_tipspot_11_1, location=(106.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_11_2': TipSpot(name=tips_02_tipspot_11_2, location=(106.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_11_3': TipSpot(name=tips_02_tipspot_11_3, location=(106.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_11_4': TipSpot(name=tips_02_tipspot_11_4, location=(106.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_11_5': TipSpot(name=tips_02_tipspot_11_5, location=(106.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_11_6': TipSpot(name=tips_02_tipspot_11_6, location=(106.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02_tipspot_11_7': TipSpot(name=tips_02_tipspot_11_7, location=(106.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_02': TipRack(name=tips_02, size_x=122.4, size_y=82.6, size_z=20.0, location=(000.000, 000.000, 000.000)),
#   'carrier-tip carrier-spot-1': CarrierSite(name=carrier-tip carrier-spot-1, location=(006.200, 106.000, 114.950), size_x=122.4, size_y=82.6, size_z=0, category=carrier_site),
#   'tips_03_tipspot_0_0': TipSpot(name=tips_03_tipspot_0_0, location=(007.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_0_1': TipSpot(name=tips_03_tipspot_0_1, location=(007.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_0_2': TipSpot(name=tips_03_tipspot_0_2, location=(007.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_0_3': TipSpot(name=tips_03_tipspot_0_3, location=(007.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_0_4': TipSpot(name=tips_03_tipspot_0_4, location=(007.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_0_5': TipSpot(name=tips_03_tipspot_0_5, location=(007.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_0_6': TipSpot(name=tips_03_tipspot_0_6, location=(007.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_0_7': TipSpot(name=tips_03_tipspot_0_7, location=(007.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_1_0': TipSpot(name=tips_03_tipspot_1_0, location=(016.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_1_1': TipSpot(name=tips_03_tipspot_1_1, location=(016.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_1_2': TipSpot(name=tips_03_tipspot_1_2, location=(016.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_1_3': TipSpot(name=tips_03_tipspot_1_3, location=(016.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_1_4': TipSpot(name=tips_03_tipspot_1_4, location=(016.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_1_5': TipSpot(name=tips_03_tipspot_1_5, location=(016.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_1_6': TipSpot(name=tips_03_tipspot_1_6, location=(016.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_1_7': TipSpot(name=tips_03_tipspot_1_7, location=(016.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_2_0': TipSpot(name=tips_03_tipspot_2_0, location=(025.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_2_1': TipSpot(name=tips_03_tipspot_2_1, location=(025.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_2_2': TipSpot(name=tips_03_tipspot_2_2, location=(025.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_2_3': TipSpot(name=tips_03_tipspot_2_3, location=(025.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_2_4': TipSpot(name=tips_03_tipspot_2_4, location=(025.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_2_5': TipSpot(name=tips_03_tipspot_2_5, location=(025.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_2_6': TipSpot(name=tips_03_tipspot_2_6, location=(025.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_2_7': TipSpot(name=tips_03_tipspot_2_7, location=(025.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_3_0': TipSpot(name=tips_03_tipspot_3_0, location=(034.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_3_1': TipSpot(name=tips_03_tipspot_3_1, location=(034.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_3_2': TipSpot(name=tips_03_tipspot_3_2, location=(034.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_3_3': TipSpot(name=tips_03_tipspot_3_3, location=(034.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_3_4': TipSpot(name=tips_03_tipspot_3_4, location=(034.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_3_5': TipSpot(name=tips_03_tipspot_3_5, location=(034.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_3_6': TipSpot(name=tips_03_tipspot_3_6, location=(034.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_3_7': TipSpot(name=tips_03_tipspot_3_7, location=(034.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_4_0': TipSpot(name=tips_03_tipspot_4_0, location=(043.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_4_1': TipSpot(name=tips_03_tipspot_4_1, location=(043.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_4_2': TipSpot(name=tips_03_tipspot_4_2, location=(043.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_4_3': TipSpot(name=tips_03_tipspot_4_3, location=(043.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_4_4': TipSpot(name=tips_03_tipspot_4_4, location=(043.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_4_5': TipSpot(name=tips_03_tipspot_4_5, location=(043.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_4_6': TipSpot(name=tips_03_tipspot_4_6, location=(043.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_4_7': TipSpot(name=tips_03_tipspot_4_7, location=(043.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_5_0': TipSpot(name=tips_03_tipspot_5_0, location=(052.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_5_1': TipSpot(name=tips_03_tipspot_5_1, location=(052.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_5_2': TipSpot(name=tips_03_tipspot_5_2, location=(052.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_5_3': TipSpot(name=tips_03_tipspot_5_3, location=(052.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_5_4': TipSpot(name=tips_03_tipspot_5_4, location=(052.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_5_5': TipSpot(name=tips_03_tipspot_5_5, location=(052.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_5_6': TipSpot(name=tips_03_tipspot_5_6, location=(052.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_5_7': TipSpot(name=tips_03_tipspot_5_7, location=(052.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_6_0': TipSpot(name=tips_03_tipspot_6_0, location=(061.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_6_1': TipSpot(name=tips_03_tipspot_6_1, location=(061.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_6_2': TipSpot(name=tips_03_tipspot_6_2, location=(061.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_6_3': TipSpot(name=tips_03_tipspot_6_3, location=(061.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_6_4': TipSpot(name=tips_03_tipspot_6_4, location=(061.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_6_5': TipSpot(name=tips_03_tipspot_6_5, location=(061.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_6_6': TipSpot(name=tips_03_tipspot_6_6, location=(061.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_6_7': TipSpot(name=tips_03_tipspot_6_7, location=(061.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_7_0': TipSpot(name=tips_03_tipspot_7_0, location=(070.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_7_1': TipSpot(name=tips_03_tipspot_7_1, location=(070.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_7_2': TipSpot(name=tips_03_tipspot_7_2, location=(070.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_7_3': TipSpot(name=tips_03_tipspot_7_3, location=(070.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_7_4': TipSpot(name=tips_03_tipspot_7_4, location=(070.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_7_5': TipSpot(name=tips_03_tipspot_7_5, location=(070.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_7_6': TipSpot(name=tips_03_tipspot_7_6, location=(070.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_7_7': TipSpot(name=tips_03_tipspot_7_7, location=(070.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_8_0': TipSpot(name=tips_03_tipspot_8_0, location=(079.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_8_1': TipSpot(name=tips_03_tipspot_8_1, location=(079.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_8_2': TipSpot(name=tips_03_tipspot_8_2, location=(079.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_8_3': TipSpot(name=tips_03_tipspot_8_3, location=(079.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_8_4': TipSpot(name=tips_03_tipspot_8_4, location=(079.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_8_5': TipSpot(name=tips_03_tipspot_8_5, location=(079.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_8_6': TipSpot(name=tips_03_tipspot_8_6, location=(079.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_8_7': TipSpot(name=tips_03_tipspot_8_7, location=(079.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_9_0': TipSpot(name=tips_03_tipspot_9_0, location=(088.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_9_1': TipSpot(name=tips_03_tipspot_9_1, location=(088.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_9_2': TipSpot(name=tips_03_tipspot_9_2, location=(088.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_9_3': TipSpot(name=tips_03_tipspot_9_3, location=(088.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_9_4': TipSpot(name=tips_03_tipspot_9_4, location=(088.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_9_5': TipSpot(name=tips_03_tipspot_9_5, location=(088.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_9_6': TipSpot(name=tips_03_tipspot_9_6, location=(088.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_9_7': TipSpot(name=tips_03_tipspot_9_7, location=(088.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_10_0': TipSpot(name=tips_03_tipspot_10_0, location=(097.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_10_1': TipSpot(name=tips_03_tipspot_10_1, location=(097.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_10_2': TipSpot(name=tips_03_tipspot_10_2, location=(097.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_10_3': TipSpot(name=tips_03_tipspot_10_3, location=(097.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_10_4': TipSpot(name=tips_03_tipspot_10_4, location=(097.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_10_5': TipSpot(name=tips_03_tipspot_10_5, location=(097.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_10_6': TipSpot(name=tips_03_tipspot_10_6, location=(097.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_10_7': TipSpot(name=tips_03_tipspot_10_7, location=(097.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_11_0': TipSpot(name=tips_03_tipspot_11_0, location=(106.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_11_1': TipSpot(name=tips_03_tipspot_11_1, location=(106.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_11_2': TipSpot(name=tips_03_tipspot_11_2, location=(106.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_11_3': TipSpot(name=tips_03_tipspot_11_3, location=(106.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_11_4': TipSpot(name=tips_03_tipspot_11_4, location=(106.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_11_5': TipSpot(name=tips_03_tipspot_11_5, location=(106.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_11_6': TipSpot(name=tips_03_tipspot_11_6, location=(106.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03_tipspot_11_7': TipSpot(name=tips_03_tipspot_11_7, location=(106.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_03': TipRack(name=tips_03, size_x=122.4, size_y=82.6, size_z=20.0, location=(000.000, 000.000, 000.000)),
#   'carrier-tip carrier-spot-2': CarrierSite(name=carrier-tip carrier-spot-2, location=(006.200, 202.000, 114.950), size_x=122.4, size_y=82.6, size_z=0, category=carrier_site),
#   'tips_04_tipspot_0_0': TipSpot(name=tips_04_tipspot_0_0, location=(007.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_04_tipspot_0_1': TipSpot(name=tips_04_tipspot_0_1, location=(007.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_04_tipspot_0_2': TipSpot(name=tips_04_tipspot_0_2, location=(007.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_04_tipspot_0_3': TipSpot(name=tips_04_tipspot_0_3, location=(007.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_04_tipspot_0_4': TipSpot(name=tips_04_tipspot_0_4, location=(007.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_04_tipspot_0_5': TipSpot(name=tips_04_tipspot_0_5, location=(007.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_04_tipspot_0_6': TipSpot(name=tips_04_tipspot_0_6, location=(007.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_04_tipspot_0_7': TipSpot(name=tips_04_tipspot_0_7, location=(007.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_04_tipspot_1_0': TipSpot(name=tips_04_tipspot_1_0, location=(016.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_04_tipspot_1_1': TipSpot(name=tips_04_tipspot_1_1, location=(016.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_04_tipspot_1_2': TipSpot(name=tips_04_tipspot_1_2, location=(016.200, 050.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_04_tipspot_1_3': TipSpot(name=tips_04_tipspot_1_3, location=(016.200, 041.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_04_tipspot_1_4': TipSpot(name=tips_04_tipspot_1_4, location=(016.200, 032.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_04_tipspot_1_5': TipSpot(name=tips_04_tipspot_1_5, location=(016.200, 023.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_04_tipspot_1_6': TipSpot(name=tips_04_tipspot_1_6, location=(016.200, 014.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_04_tipspot_1_7': TipSpot(name=tips_04_tipspot_1_7, location=(016.200, 005.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_04_tipspot_2_0': TipSpot(name=tips_04_tipspot_2_0, location=(025.200, 068.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
#   'tips_04_tipspot_2_1': TipSpot(name=tips_04_tipspot_2_1, location=(025.200, 059.300, -83.500), size_x=9.0, size_y=9.0, size_z=0, category=tip_spot),
# ...
#   'plate_02_well_11_1': Well(name=plate_02_well_11_1, location=(108.500, 061.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_02_well_11_2': Well(name=plate_02_well_11_2, location=(108.500, 052.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_02_well_11_3': Well(name=plate_02_well_11_3, location=(108.500, 043.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_02_well_11_4': Well(name=plate_02_well_11_4, location=(108.500, 034.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_02_well_11_5': Well(name=plate_02_well_11_5, location=(108.500, 025.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_02_well_11_6': Well(name=plate_02_well_11_6, location=(108.500, 016.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_02_well_11_7': Well(name=plate_02_well_11_7, location=(108.500, 007.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_02': Plate(name=plate_02, size_x=127.0, size_y=86.0, size_z=42.0, location=(000.000, 000.000, 000.000), one_dot_max=40.0),
#   'carrier-plate carrier-spot-1': CarrierSite(name=carrier-plate carrier-spot-1, location=(004.000, 104.500, 086.150), size_x=127.0, size_y=86.0, size_z=0, category=carrier_site),
#   'plate_03_well_0_0': Well(name=plate_03_well_0_0, location=(009.500, 070.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_0_1': Well(name=plate_03_well_0_1, location=(009.500, 061.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_0_2': Well(name=plate_03_well_0_2, location=(009.500, 052.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_0_3': Well(name=plate_03_well_0_3, location=(009.500, 043.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_0_4': Well(name=plate_03_well_0_4, location=(009.500, 034.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_0_5': Well(name=plate_03_well_0_5, location=(009.500, 025.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_0_6': Well(name=plate_03_well_0_6, location=(009.500, 016.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_0_7': Well(name=plate_03_well_0_7, location=(009.500, 007.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_1_0': Well(name=plate_03_well_1_0, location=(018.500, 070.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_1_1': Well(name=plate_03_well_1_1, location=(018.500, 061.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_1_2': Well(name=plate_03_well_1_2, location=(018.500, 052.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_1_3': Well(name=plate_03_well_1_3, location=(018.500, 043.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_1_4': Well(name=plate_03_well_1_4, location=(018.500, 034.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_1_5': Well(name=plate_03_well_1_5, location=(018.500, 025.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_1_6': Well(name=plate_03_well_1_6, location=(018.500, 016.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_1_7': Well(name=plate_03_well_1_7, location=(018.500, 007.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_2_0': Well(name=plate_03_well_2_0, location=(027.500, 070.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_2_1': Well(name=plate_03_well_2_1, location=(027.500, 061.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_2_2': Well(name=plate_03_well_2_2, location=(027.500, 052.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_2_3': Well(name=plate_03_well_2_3, location=(027.500, 043.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_2_4': Well(name=plate_03_well_2_4, location=(027.500, 034.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_2_5': Well(name=plate_03_well_2_5, location=(027.500, 025.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_2_6': Well(name=plate_03_well_2_6, location=(027.500, 016.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_2_7': Well(name=plate_03_well_2_7, location=(027.500, 007.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_3_0': Well(name=plate_03_well_3_0, location=(036.500, 070.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_3_1': Well(name=plate_03_well_3_1, location=(036.500, 061.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_3_2': Well(name=plate_03_well_3_2, location=(036.500, 052.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_3_3': Well(name=plate_03_well_3_3, location=(036.500, 043.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_3_4': Well(name=plate_03_well_3_4, location=(036.500, 034.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_3_5': Well(name=plate_03_well_3_5, location=(036.500, 025.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_3_6': Well(name=plate_03_well_3_6, location=(036.500, 016.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_3_7': Well(name=plate_03_well_3_7, location=(036.500, 007.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_4_0': Well(name=plate_03_well_4_0, location=(045.500, 070.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_4_1': Well(name=plate_03_well_4_1, location=(045.500, 061.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_4_2': Well(name=plate_03_well_4_2, location=(045.500, 052.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_4_3': Well(name=plate_03_well_4_3, location=(045.500, 043.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_4_4': Well(name=plate_03_well_4_4, location=(045.500, 034.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_4_5': Well(name=plate_03_well_4_5, location=(045.500, 025.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_4_6': Well(name=plate_03_well_4_6, location=(045.500, 016.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_4_7': Well(name=plate_03_well_4_7, location=(045.500, 007.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_5_0': Well(name=plate_03_well_5_0, location=(054.500, 070.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_5_1': Well(name=plate_03_well_5_1, location=(054.500, 061.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_5_2': Well(name=plate_03_well_5_2, location=(054.500, 052.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_5_3': Well(name=plate_03_well_5_3, location=(054.500, 043.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_5_4': Well(name=plate_03_well_5_4, location=(054.500, 034.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_5_5': Well(name=plate_03_well_5_5, location=(054.500, 025.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_5_6': Well(name=plate_03_well_5_6, location=(054.500, 016.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_5_7': Well(name=plate_03_well_5_7, location=(054.500, 007.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_6_0': Well(name=plate_03_well_6_0, location=(063.500, 070.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_6_1': Well(name=plate_03_well_6_1, location=(063.500, 061.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_6_2': Well(name=plate_03_well_6_2, location=(063.500, 052.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_6_3': Well(name=plate_03_well_6_3, location=(063.500, 043.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_6_4': Well(name=plate_03_well_6_4, location=(063.500, 034.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_6_5': Well(name=plate_03_well_6_5, location=(063.500, 025.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_6_6': Well(name=plate_03_well_6_6, location=(063.500, 016.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_6_7': Well(name=plate_03_well_6_7, location=(063.500, 007.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_7_0': Well(name=plate_03_well_7_0, location=(072.500, 070.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_7_1': Well(name=plate_03_well_7_1, location=(072.500, 061.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_7_2': Well(name=plate_03_well_7_2, location=(072.500, 052.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_7_3': Well(name=plate_03_well_7_3, location=(072.500, 043.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_7_4': Well(name=plate_03_well_7_4, location=(072.500, 034.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_7_5': Well(name=plate_03_well_7_5, location=(072.500, 025.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_7_6': Well(name=plate_03_well_7_6, location=(072.500, 016.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_7_7': Well(name=plate_03_well_7_7, location=(072.500, 007.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_8_0': Well(name=plate_03_well_8_0, location=(081.500, 070.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_8_1': Well(name=plate_03_well_8_1, location=(081.500, 061.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_8_2': Well(name=plate_03_well_8_2, location=(081.500, 052.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_8_3': Well(name=plate_03_well_8_3, location=(081.500, 043.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_8_4': Well(name=plate_03_well_8_4, location=(081.500, 034.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_8_5': Well(name=plate_03_well_8_5, location=(081.500, 025.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_8_6': Well(name=plate_03_well_8_6, location=(081.500, 016.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_8_7': Well(name=plate_03_well_8_7, location=(081.500, 007.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_9_0': Well(name=plate_03_well_9_0, location=(090.500, 070.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_9_1': Well(name=plate_03_well_9_1, location=(090.500, 061.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_9_2': Well(name=plate_03_well_9_2, location=(090.500, 052.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_9_3': Well(name=plate_03_well_9_3, location=(090.500, 043.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_9_4': Well(name=plate_03_well_9_4, location=(090.500, 034.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_9_5': Well(name=plate_03_well_9_5, location=(090.500, 025.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_9_6': Well(name=plate_03_well_9_6, location=(090.500, 016.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_9_7': Well(name=plate_03_well_9_7, location=(090.500, 007.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_10_0': Well(name=plate_03_well_10_0, location=(099.500, 070.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_10_1': Well(name=plate_03_well_10_1, location=(099.500, 061.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_10_2': Well(name=plate_03_well_10_2, location=(099.500, 052.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_10_3': Well(name=plate_03_well_10_3, location=(099.500, 043.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_10_4': Well(name=plate_03_well_10_4, location=(099.500, 034.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_10_5': Well(name=plate_03_well_10_5, location=(099.500, 025.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_10_6': Well(name=plate_03_well_10_6, location=(099.500, 016.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_10_7': Well(name=plate_03_well_10_7, location=(099.500, 007.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_11_0': Well(name=plate_03_well_11_0, location=(108.500, 070.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_11_1': Well(name=plate_03_well_11_1, location=(108.500, 061.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_11_2': Well(name=plate_03_well_11_2, location=(108.500, 052.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_11_3': Well(name=plate_03_well_11_3, location=(108.500, 043.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_11_4': Well(name=plate_03_well_11_4, location=(108.500, 034.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_11_5': Well(name=plate_03_well_11_5, location=(108.500, 025.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_11_6': Well(name=plate_03_well_11_6, location=(108.500, 016.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03_well_11_7': Well(name=plate_03_well_11_7, location=(108.500, 007.000, 001.000), size_x=9.0, size_y=9.0, size_z=9, category=well),
#   'plate_03': Plate(name=plate_03, size_x=127.0, size_y=86.0, size_z=42.0, location=(000.000, 000.000, 000.000), one_dot_max=40.0),
#   'carrier-plate carrier-spot-2': CarrierSite(name=carrier-plate carrier-spot-2, location=(004.000, 200.500, 086.150), size_x=127.0, size_y=86.0, size_z=0, category=carrier_site),
#   'carrier-plate carrier-spot-3': CarrierSite(name=carrier-plate carrier-spot-3, location=(004.000, 296.500, 086.150), size_x=127.0, size_y=86.0, size_z=0, category=carrier_site),
#   'carrier-plate carrier-spot-4': CarrierSite(name=carrier-plate carrier-spot-4, location=(004.000, 392.500, 086.150), size_x=127.0, size_y=86.0, size_z=0, category=carrier_site),
#   'plate carrier': PlateCarrier(name=plate carrier, location=(257.500, 063.000, 100.000), size_x=135.0, size_y=497.0, size_z=130.0, category=plate_carrier)},
#  'resource_assigned_callback_callback': <bound method LiquidHandler.resource_assigned_callback of <pylabrobot.liquid_handling.liquid_handler.LiquidHandler object at 0x0624D028>>,
#  'resource_unassigned_callback_callback': <bound method LiquidHandler.resource_unassigned_callback of <pylabrobot.liquid_handling.liquid_handler.LiquidHandler object at 0x0624D028>>,
#  'num_rails': 30}

# %%
sb = SimulatorBackend(open_browser=False)
lh = LiquidHandler(backend=sb, deck=OTDeck())
await lh.setup()
sb.wait_for_connection()
# Out:
# Websocket server started at http://127.0.0.1:2121
# File server started at http://127.0.0.1:1337 . Open this URL in your browser.

# %%
from pylabrobot.resources import Cos_96_DW_1mL
plate_1 = Cos_96_DW_1mL(name='plate_1')
plate_2 = Cos_96_DW_1mL(name='plate_2')

lh.deck.assign_child_at_slot(plate_1, slot = 2)
lh.deck.assign_child_at_slot(plate_2, slot = 3)

# %%
from pylabrobot.resources.opentrons import opentrons_96_tiprack_300ul
tips = opentrons_96_tiprack_300ul(name = 'tips')

# %%
lh.deck.assign_child_at_slot(tips, slot = 4)

# %%
await sb.fill_tip_rack(tips)

# %%
await sb.adjust_well_volume(plate_1, pattern=[[500]*12]*8)

# %%
await lh.pick_up_tips(tips["A1"])
await lh.aspirate(plate_1["A2"], vols=[300])
await lh.dispense(plate_2["A1"], vols=[300])
await lh.drop_tips(tips["A1"])
